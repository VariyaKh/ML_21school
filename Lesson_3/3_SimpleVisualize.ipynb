# %% [markdown]
# # Визуализация данных
# Автор: Хужина Вария
# Репозиторий курса: https://github.com/VariyaKh/ML_21school

# %% [markdown]
# Для виуализации данных подключим библиотеку matplotlib и seaborn. Если у вас не установлен seaborn, воспользуйтесь pip3

# %%
# !pip3 install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Чтение данных

# %%
data = pd.read_csv("data/who_suicide_statistics.csv", sep=',')

# %%
data.head()
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1985  female  15-24 years          NaN    277900.0
# 1  Albania  1985  female  25-34 years          NaN    246800.0
# 2  Albania  1985  female  35-54 years          NaN    267500.0
# 3  Albania  1985  female   5-14 years          NaN    298300.0
# 4  Albania  1985  female  55-74 years          NaN    138700.0

# %% [markdown]
# ## Гистограмма

# %% [markdown]
# Посмотрим на общее распределение колиества суицидов с помощью пандосовского метода hist()

# %%
data['suicides_no'].hist();

# %% [markdown]
# Распределения для всех численных данных

# %%
plt.rcParams['figure.figsize'] = (16, 16) # изменения размера графиков
data.hist();

# %% [markdown]
# ## Тепловая карта

# %% [markdown]
# Степень корреляции (линейной зависисомти) признаков, чем светлее тем больше корреляция

# %%
plt.rcParams['figure.figsize'] = (8, 8)
sns.heatmap(data.corr());

# %% [markdown]
# ## BoxPlot или ящик с усами

# %% [markdown]
# Посмотрим на распределение колиества суицидов среди мужчин и женщин в Росии.

# %%
data_ru = data[data['country'] == 'Russian Federation'].fillna(0)
data_ru = data_s[data_s['suicides_no'] > 0]

# %% [markdown]
# Из wiki:
# BoxPlot в удобной форме показывает медиану (или, если нужно, среднее), нижний и верхний квартили, минимальное и максимальное значение выборки и выбросы. Несколько таких ящиков можно нарисовать бок о бок, чтобы визуально сравнивать одно распределение с другим; их можно располагать как горизонтально, так и вертикально.

# %%
plt.rcParams['figure.figsize'] = (4, 4)
sns.boxplot(x='sex', y='suicides_no', data=data_ru);

# %% [markdown]
# Кажется мужчины более склонны к суициду, чем женщины

# %% [markdown]
# Тоже самое можно сделать и с помощью violinplot

# %%
sns.violinplot(x='sex', y='suicides_no', data=data_ru);

# %% [markdown]
# Количество людей по возрастам

# %%
sns.countplot(x='sex', hue='age', data=data_ru)
